# %%
# !pip install mysql-connector-python SQLAlchemy pandas

# %%
import mysql.connector
from sqlalchemy import create_engine
import pandas as pd

# %%
# MySQL database connection information
db_user = 'root'
db_password = '!Two3456789'
db_host = 'localhost'  # or your database server's IP
db_port = '3306'  # default MySQL port
db_name = 'projects'

# SQLAlchemy engine connection string
connection_string = f'mysql+mysqlconnector://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}'

# create the engine using SQLAlchemy
engine = create_engine(connection_string)

# %%
# test connection
connection = engine.connect()
print("Connected to the database!")

# load ipython-sql extension
# %load_ext sql

# connect to the database using the created engine
# %sql $connection_string
# Out:
# Connected to the database!

# %%
# %reload_ext sql

# %%
# %%sql
#
# # display top 5 dataframe
#
# select *
# from hr
# limit 5
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 5 rows affected.
# [('00-0037846', 'Kimmy', 'Walczynski', '1991-06-04', 'Male', 'Hispanic or Latino', 'Engineering', 'Programmer Analyst I', 'Headquarters', '1/20/2002', '', 'Cleveland', 'Ohio'),
#  ('00-0041533', 'Ignatius', 'Springett', '1984-06-29', 'Male', 'White', 'Business Development', 'Business Analyst', 'Headquarters', '04-08-19', '', 'Cleveland', 'Ohio'),
#  ('00-0045747', 'Corbie', 'Bittlestone', '1989-07-29', 'Male', 'Black or African American', 'Sales', 'Solutions Engineer Manager', 'Headquarters', '10-12-10', '', 'Cleveland', 'Ohio'),
#  ('00-0055274', 'Baxy', 'Matton', '1982-09-14', 'Female', 'White', 'Services', 'Service Tech', 'Headquarters', '04-10-05', '', 'Cleveland', 'Ohio'),
#  ('00-0076100', 'Terrell', 'Suff', '1994-04-11', 'Female', 'Two or More Races', 'Product Management', 'Business Analyst', 'Remote', '9/29/2010', '2029-10-29 06:09:38 UTC', 'Flint', 'Michigan')]

# %%
# %%sql
#
# #check type of columns
#
# describe hr
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 13 rows affected.
# [('emp_id', 'text', 'YES', '', None, ''),
#  ('first_name', 'text', 'YES', '', None, ''),
#  ('last_name', 'text', 'YES', '', None, ''),
#  ('birthdate', 'text', 'YES', '', None, ''),
#  ('gender', 'text', 'YES', '', None, ''),
#  ('race', 'text', 'YES', '', None, ''),
#  ('department', 'text', 'YES', '', None, ''),
#  ('jobtitle', 'text', 'YES', '', None, ''),
#  ('location', 'text', 'YES', '', None, ''),
#  ('hire_date', 'text', 'YES', '', None, ''),
#  ('termdate', 'text', 'YES', '', None, ''),
#  ('location_city', 'text', 'YES', '', None, ''),
#  ('location_state', 'text', 'YES', '', None, '')]

# %%
# %%sql
#
# # change the ï»¿id column to emp_id
#
# alter table hr
# rename column ï»¿id to emp_id
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# (mysql.connector.errors.ProgrammingError) 1054 (42S22): Unknown column 'ï»¿id' in 'hr'
# [SQL: alter table hr
# rename column ï»¿id to emp_id]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql
#
# # enable update
#
# set sql_safe_updates = 0
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 0 rows affected.
# []

# %%
# %%sql
#
# # change birthdate format to YYYY-MM-DD
#
# update hr
# set birthdate =
# 	case
# 		when birthdate like '%/%' then date_format(str_to_date(birthdate, '%m/%d/%Y'), '%Y-%m-%d')
# 		when birthdate like '%-%' then date_format(str_to_date(birthdate, '%m-%d-%Y'), '%Y-%m-%d')
# 		else birthdate #keep the original value if none of the above conditions are met
# 	end
# where birthdate is not null
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# (mysql.connector.errors.DatabaseError) 1411 (HY000): Incorrect datetime value: '1991-06-04' for function str_to_date
# [SQL: # change birthdate format to YYYY-MM-DD
#
# update hr
# set birthdate =
# 	case
# 		when birthdate like '%/%' then date_format(str_to_date(birthdate, '%m/%d/%Y'), '%Y-%m-%d')
# 		when birthdate like '%-%' then date_format(str_to_date(birthdate, '%m-%d-%Y'), '%Y-%m-%d')
# 		else birthdate #keep the original value if none of the above conditions are met
# 	end
# where birthdate is not null]
# (Background on this error at: https://sqlalche.me/e/20/4xp6)

# %%
# %%sql
#
# # change str to date format for birthdate column
# alter table hr
# modify column birthdate date
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 22214 rows affected.
# []

# %%
# %%sql
#
# # change hiredate format same as birthdate
#
# update hr
# set hire_date =
# 	case
# 		when hire_date like '%/%' then date_format(str_to_date(hire_date, '%m/%d/%Y'), '%Y-%m-%d')
# 		when hire_date like '%-%' then date_format(str_to_date(hire_date, '%m-%d-%Y'), '%Y-%m-%d')
# 		else hire_date -- keep the original value if none of the above conditions are met
# 	end
# where hire_date is not null
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 22214 rows affected.
# []

# %%
# %%sql
#
# # change str to date format for hire_date column
# alter table hr
# modify column hire_date date;
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 22214 rows affected.
# []

# %%
# %%sql
#
# select birthdate,
#     date_format(birthdate, '%d-%m-%Y') as new_birthdate
# from hr
# where birthdate is not null
# limit 5
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 5 rows affected.
# [(datetime.date(1991, 6, 4), '04-06-1991'),
#  (datetime.date(1984, 6, 29), '29-06-1984'),
#  (datetime.date(1989, 7, 29), '29-07-1989'),
#  (datetime.date(1982, 9, 14), '14-09-1982'),
#  (datetime.date(1994, 4, 11), '11-04-1994')]

# %%
# %%sql
#
# # change termdate into date format
#
# update hr
# set termdate = case
#     when termdate regexp '^[0-9]{4}-[0-9]{2}-[0-9]{2} [0-9]{2}:[0-9]{2}:[0-9]{2} UTC$'
#     then date(str_to_date(termdate, '%Y-%m-%d %H:%i:%s UTC')) -- %i for minutes
#     else termdate -- Keep the original value if do not meet above conditions
# end
# where termdate is not null
#   and termdate != '' and termdate != ' '
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 3929 rows affected.
# []

# %%
# %%sql
#
# # disable strict mode
# SHOW VARIABLES LIKE 'sql_mode';
# SET sql_mode = ''
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 1 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
#
# # set all the blank values in termdate with NULL
#
# update hr
# set termdate = NULL
# where termdate = '0000-00-00' OR termdate = '' OR termdate = ' '
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 18285 rows affected.
# []

# %%
# %%sql
#
# # change termdate column type to date format
# alter table hr
# modify column termdate date
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 22214 rows affected.
# []

# %%
# %%sql
#
# # add column age
#
# alter table hr
# add column age int
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 0 rows affected.
# []

# %%
# %%sql
#
# update hr
# set age = timestampdiff(year, birthdate, curdate())
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 22214 rows affected.
# []

# %% [markdown]
# ## QUESTIONS

# %% [markdown]
# ## 1. What is the gender breakdown of employees in the company?

# %%
# %%sql
#
# select gender, count(*) as count
# from hr
# where age >= 18
# group by gender
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 3 rows affected.
# [('Male', 10794), ('Female', 9876), ('Non-Conforming', 577)]

# %% [markdown]
# # 2. What is the race/ethnicity breakdown of employees in the company?

# %%
# %%sql
#
# select race, count(*) as count
# from hr
# where age >= 18
# group by race
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 7 rows affected.
# [('Hispanic or Latino', 2402),
#  ('White', 6057),
#  ('Black or African American', 3443),
#  ('Two or More Races', 3508),
#  ('Asian', 3388),
#  ('American Indian or Alaska Native', 1273),
#  ('Native Hawaiian or Other Pacific Islander', 1176)]

# %% [markdown]
# ## 3. What is the age distribution of employees in the company?

# %%
# %%sql
#
# select min(age) as youngest, max(age) as oldest
# from hr
# where age >=18
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 1 rows affected.
# [(22, 59)]

# %%
# %%sql
#
# select
# 	case
# 		when age <=29 then '20s'
#         when age between 30 and 39 then '30s'
#         when age between 40 and 49 then '40s'
#         when age between 50 and 59 then '50s'
#         else '60s'
# 	end as age_group,
#     count(*) as count
# from hr
# where age >= 18
# group by age_group
# order by age_group
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 4 rows affected.
# [('20s', 4584), ('30s', 6154), ('40s', 5889), ('50s', 4620)]

# %%
# %%sql
#
# select
# 	case
# 		when age >= 18 and age <= 24 then '18-24'
#         when age >= 25 and age <= 29 then '25-29'
#         when age >= 30 and age <= 34 then '30-34'
#         when age >= 35 and age <= 39 then '35-39'
#         when age >= 40 and age <= 44 then '40-44'
#         when age >= 45 and age <= 49 then '45-49'
#         when age >= 50 and age <= 54 then '50-54'
#         when age >= 55 and age <= 59 then '55-59'
#         else '60+'
# 	end as age_group,
#     count(*) as count
# from hr
# where age >= 18
# group by age_group
# order by age_group
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 8 rows affected.
# [('18-24', 1620),
#  ('25-29', 2964),
#  ('30-34', 3005),
#  ('35-39', 3149),
#  ('40-44', 2957),
#  ('45-49', 2932),
#  ('50-54', 2990),
#  ('55-59', 1630)]

# %%
# %%sql
#
# select
# 	case
# 		when age >= 18 and age <= 24 then '18-24'
#         when age >= 25 and age <= 29 then '25-29'
#         when age >= 30 and age <= 34 then '30-34'
#         when age >= 35 and age <= 39 then '35-39'
#         when age >= 40 and age <= 44 then '40-44'
#         when age >= 45 and age <= 49 then '45-49'
#         when age >= 50 and age <= 54 then '50-54'
#         when age >= 55 and age <= 59 then '55-59'
#         else '60+'
# 	end as age_group, gender,
#     count(*) as count
# from hr
# where age >= 18
# group by age_group, gender
# order by age_group, gender
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 24 rows affected.
# [('18-24', 'Female', 727),
#  ('18-24', 'Male', 853),
#  ('18-24', 'Non-Conforming', 40),
#  ('25-29', 'Female', 1371),
#  ('25-29', 'Male', 1523),
#  ('25-29', 'Non-Conforming', 70),
#  ('30-34', 'Female', 1415),
#  ('30-34', 'Male', 1504),
#  ('30-34', 'Non-Conforming', 86),
#  ('35-39', 'Female', 1445),
#  ('35-39', 'Male', 1611),
#  ('35-39', 'Non-Conforming', 93),
#  ('40-44', 'Female', 1335),
#  ('40-44', 'Male', 1553),
#  ('40-44', 'Non-Conforming', 69),
#  ('45-49', 'Female', 1371),
#  ('45-49', 'Male', 1475),
#  ('45-49', 'Non-Conforming', 86),
#  ('50-54', 'Female', 1427),
#  ('50-54', 'Male', 1479),
#  ('50-54', 'Non-Conforming', 84),
#  ('55-59', 'Female', 785),
#  ('55-59', 'Male', 796),
#  ('55-59', 'Non-Conforming', 49)]

# %% [markdown]
# ## 4. How many employees work at headquarters versus remote locations?

# %%
# %%sql
#
# select location, count(*) as count
# from hr
# where location in ('Headquarters' ,'Remote') and age >= 18
# group by location
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 2 rows affected.
# [('Headquarters', 15992), ('Remote', 5255)]

# %% [markdown]
# ## 5. What is the average length of employment for employees who have been terminated?

# %%
# %%sql
#
# select round(avg(datediff(termdate, hire_date)/365),0) as avg_length_year
# from hr
# where termdate is not null and termdate <= curdate() and age >= 18
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 1 rows affected.
# [(Decimal('8'),)]

# %% [markdown]
# ## 6. a) How does the gender distribution vary across departments?

# %%
# %%sql
#
# select department, gender, count(*) as count
# from hr
# where age >= 18
# group by department, gender
# order by department, gender
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 38 rows affected.
# [('Accounting', 'Female', 1462),
#  ('Accounting', 'Male', 1640),
#  ('Accounting', 'Non-Conforming', 90),
#  ('Auditing', 'Female', 23),
#  ('Auditing', 'Male', 27),
#  ('Business Development', 'Female', 722),
#  ('Business Development', 'Male', 798),
#  ('Business Development', 'Non-Conforming', 49),
#  ('Engineering', 'Female', 2983),
#  ('Engineering', 'Male', 3225),
#  ('Engineering', 'Non-Conforming', 179),
#  ('Human Resources', 'Female', 820),
#  ('Human Resources', 'Male', 867),
#  ('Human Resources', 'Non-Conforming', 40),
#  ('Legal', 'Female', 134),
#  ('Legal', 'Male', 158),
#  ('Legal', 'Non-Conforming', 7),
#  ('Marketing', 'Female', 230),
#  ('Marketing', 'Male', 245),
#  ('Marketing', 'Non-Conforming', 5),
#  ('Product Management', 'Female', 270),
#  ('Product Management', 'Male', 338),
#  ('Product Management', 'Non-Conforming', 15),
#  ('Research and Development', 'Female', 491),
# ...

# %% [markdown]
# ## 6. b) How does the gender distribution vary across job titles?

# %%
# %%sql
#
# select jobtitle, gender, count(*) as count
# from hr
# where age >= 18
# group by jobtitle, gender
# order by jobtitle, gender
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 493 rows affected.
# [('Account Coordinator', 'Male', 2),
#  ('Account Executive', 'Female', 245),
#  ('Account Executive', 'Male', 224),
#  ('Account Executive', 'Non-Conforming', 10),
#  ('Account Manager', 'Female', 99),
#  ('Account Manager', 'Male', 101),
#  ('Account Manager', 'Non-Conforming', 5),
#  ('Accountant I', 'Female', 29),
#  ('Accountant I', 'Male', 43),
#  ('Accountant I', 'Non-Conforming', 3),
#  ('Accountant II', 'Female', 44),
#  ('Accountant II', 'Male', 36),
#  ('Accountant II', 'Non-Conforming', 2),
#  ('Accountant III', 'Female', 42),
#  ('Accountant III', 'Male', 38),
#  ('Accountant III', 'Non-Conforming', 3),
#  ('Accountant IV', 'Female', 38),
#  ('Accountant IV', 'Male', 45),
#  ('Accountant IV', 'Non-Conforming', 3),
#  ('Accounting Assistant I', 'Female', 39),
#  ('Accounting Assistant I', 'Male', 44),
#  ('Accounting Assistant I', 'Non-Conforming', 3),
# ...

# %% [markdown]
# ## 7. What is the distribution of job titles across the company?

# %%
# %%sql
#
# select jobtitle, count(*) as count
# from hr
# where age >= 18
# group by jobtitle
# order by count desc
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 185 rows affected.
# [('Research Assistant II', 718),
#  ('Business Analyst', 684),
#  ('Human Resources Analyst II', 591),
#  ('Research Assistant I', 507),
#  ('Account Executive', 479),
#  ('Data Visualization Specialist', 434),
#  ('Staff Accountant I', 427),
#  ('Human Resources Analyst', 393),
#  ('Software Engineer I', 378),
#  ('Systems Administrator I', 359),
#  ('Analyst Programmer', 348),
#  ('Data Coordiator', 348),
#  ('Senior Developer', 346),
#  ('Project Manager', 329),
#  ('Software Consultant', 327),
#  ('Business Systems Development Analyst', 326),
#  ('Help Desk Technician', 322),
#  ('Service Manager', 319),
#  ('Service Tech III', 319),
#  ('Service Tech', 315),
#  ('Service Tech II', 315),
#  ('Service Coordinator', 313),
#  ('Desktop Support Technician', 302),
#  ('Senior Cost Accountant', 301),
#  ('Tax Accountant', 294),
#  ('Structural Engineer', 293),
#  ('Cost Accountant', 291),
# ...

# %% [markdown]
# ## 8. Which department has the highest turnover rate?

# %%
# %%sql
#
# select
#     department,
#     (COUNT(*) / (select count(*) from hr where hire_date <= curdate() and department = h.department)) * 100 as turnover_rate
# from hr h
# where termdate is not null and termdate <= curdate()
# group by department
# order by turnover_rate desc
# limit 1
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 1 rows affected.
# [('Auditing', Decimal('17.3077'))]

# %% [markdown]
# ## 9. a) What is the distribution of employees across locations by city and state?

# %%
# %%sql
#
# select location_city, count(*) as count
# from hr
# where age >= 18
# group by location_city

# %% [markdown]
# ## 9. b) What is the distribution of employees across locations by state?

# %%
# %%sql
#
# select location_state, count(*) as count
# from hr
# where age >= 18
# group by location_state

# %% [markdown]
# ## 10. How has the company's employee count changed over time based on hire and term dates?

# %%
# %%sql
#
# select
#     year,
#     hires,
#     terminations,
#     (hires - terminations) as net_change,
#     round(((hires - terminations) / hires * 100), 2) as net_change_percent
# from (
#     select
#         year(hire_date) as year,
#         count(*) as hires,
#         sum(
#             case
#                 when termdate is not null and termdate <= curdate() then 1
#                 else 0
#             end) as terminations
#     from hr
#     where age >= 18
#     group by year
#     order by year
# )subquery
# order by year
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 21 rows affected.
# [(2000, 211, Decimal('26'), Decimal('185'), Decimal('87.68')),
#  (2001, 1082, Decimal('197'), Decimal('885'), Decimal('81.79')),
#  (2002, 1012, Decimal('162'), Decimal('850'), Decimal('83.99')),
#  (2003, 1088, Decimal('198'), Decimal('890'), Decimal('81.80')),
#  (2004, 1087, Decimal('201'), Decimal('886'), Decimal('81.51')),
#  (2005, 1038, Decimal('189'), Decimal('849'), Decimal('81.79')),
#  (2006, 1069, Decimal('183'), Decimal('886'), Decimal('82.88')),
#  (2007, 1058, Decimal('153'), Decimal('905'), Decimal('85.54')),
#  (2008, 1061, Decimal('145'), Decimal('916'), Decimal('86.33')),
#  (2009, 1094, Decimal('154'), Decimal('940'), Decimal('85.92')),
#  (2010, 1050, Decimal('138'), Decimal('912'), Decimal('86.86')),
#  (2011, 1057, Decimal('120'), Decimal('937'), Decimal('88.65')),
#  (2012, 1059, Decimal('118'), Decimal('941'), Decimal('88.86')),
# ...

# %% [markdown]
# ## 11. What is the tenure distribution for each department?

# %%
# %%sql
#
# select department, round(avg(datediff(termdate, hire_date)/365),0) as tenure
# from hr
# where age >= 18 and termdate <= curdate() and termdate is not null
# group by department
# Out:
#  * mysql+mysqlconnector://root:***@localhost:3306/projects
# 13 rows affected.
# [('Engineering', Decimal('8')),
#  ('Services', Decimal('8')),
#  ('Human Resources', Decimal('8')),
#  ('Business Development', Decimal('8')),
#  ('Sales', Decimal('9')),
#  ('Support', Decimal('7')),
#  ('Auditing', Decimal('8')),
#  ('Training', Decimal('8')),
#  ('Accounting', Decimal('8')),
#  ('Research and Development', Decimal('8')),
#  ('Product Management', Decimal('7')),
#  ('Legal', Decimal('7')),
#  ('Marketing', Decimal('9'))]
